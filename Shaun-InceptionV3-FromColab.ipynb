# %% [markdown]
# # Source Code Notebook - InceptionV3

# %% [markdown]
# ## Google Colab Configs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Image Conversion and Validation

# %% [markdown]
# ### Conversion of JPG to JPEG
#
# ```
# pip install opencv-python
# ```

# %%
import cv2
import os
from pathlib import Path
# DATA_DIR = "dataset/AI Art vs Real Art/" # Put unzipped files to the unzipped folder and change accordingly

# For Colab:
DATA_DIR = "/content/drive/MyDrive/dataset/AI Art vs Real Art"
def jpg_to_jpeg(data_dir):
    for dir_name in os.listdir(data_dir):
        if (dir_name != '.DS_Store'):
            files = os.path.join(data_dir,dir_name)
            for filepaths in os.listdir(files):
                file_names = os.path.join(files,filepaths)
                if file_names.endswith(".jpg") or file_names.endswith(".JPG"):
                    img = cv2.imread(str(file_names))
                    cv2.imwrite(file_names[0:-4]+".jpeg", img)
                    os.remove(file_names)

# jpg_to_jpeg(data_dir="dataset/AI Art vs Real Art/AI Art")
# jpg_to_jpeg(data_dir="dataset/AI Art vs Real Art/Real")

jpg_to_jpeg(data_dir="/content/drive/MyDrive/dataset/AI Art vs Real Art/AI Art")
jpg_to_jpeg(data_dir="/content/drive/MyDrive/dataset/AI Art vs Real Art/Real")

# %% [markdown]
# ### Checking of the validity of Images in the dataset

# %%
import imghdr
IMAGE_EXTENSIONS = [".png", ".jpg", ".jpeg"]  # add there all your images file extensions
img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(DATA_DIR).rglob("*"):
    if filepath.suffix.lower() in IMAGE_EXTENSIONS:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
            os.remove(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Import Tensorflow and Keras and check on available GPU

# %%
import sys
import tensorflow as tf
import keras
import platform
import numpy as np
print(f"Python Platform: {platform.version()}")
print(f"Python Version: {sys.version}")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
print()
gpu = len(tf.config.list_physical_devices('GPU')) > 0
print(f"GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: #1 SMP PREEMPT_DYNAMIC Sun Apr 28 14:29:16 UTC 2024
# Python Version: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Tensorflow version: 2.15.0
# Keras version: 2.15.0
#
# GPU is available

# %% [markdown]
# ### Set constants for Images

# %%
BATCH_SIZE = 64
HEIGHT = 256
WIDTH = 256

# %% [markdown]
# ## By Scratch Preprocessing

# %% [markdown]
# ### Util Methods

# %%
def load_dataset(path):
    all_files = [os.path.join(path, f) for f in os.listdir(path)]
    valid_files = [f for f in all_files if f.split('.')[-1].lower() in img_type_accepted_by_tf]
    return tf.data.Dataset.from_tensor_slices(valid_files)

def split_dataset(dataset, train_size, val_size):
    train_dataset = dataset.take(train_size)
    val_dataset = dataset.skip(train_size).take(val_size)
    return train_dataset, val_dataset

def undersample_dataset(dataset, target_size):
    return dataset.take(target_size)

def load_and_preprocess_image(file_path):
    file_extension = tf.strings.split(file_path, '.')[-1]
    image = tf.io.read_file(file_path)

    # Decode based on the file extension
    if file_extension == 'png':
        image = tf.image.decode_png(image, channels=3)
    elif file_extension == 'bmp':
        image = tf.image.decode_bmp(image, channels=3)
    elif file_extension == 'gif':
        image = tf.image.decode_gif(image)
        image = tf.squeeze(image, axis=0)  # Extract the first frame
    else:  # Default to JPEG
        image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [HEIGHT, WIDTH])
    return image

def label_dataset(dataset, label):
    return dataset.map(lambda x: (x, label))

# %% [markdown]
# ### Loading and Shuffling Dataset

# %%
# AI_ART_PATH = 'dataset/AI Art vs Real Art/AI Art/AiArtData'
# REAL_ART_PATH = 'dataset/AI Art vs Real Art/Real/RealArt'
AI_ART_PATH = '/content/drive/MyDrive/dataset/AI Art vs Real Art/AI Art/AiArtData'
REAL_ART_PATH = '/content/drive/MyDrive/dataset/AI Art vs Real Art/Real/RealArt'
ai_images = load_dataset(AI_ART_PATH)
real_images = load_dataset(REAL_ART_PATH)

ai_dataset = ai_images.shuffle(buffer_size=1000, seed=1337)
real_dataset = real_images.shuffle(buffer_size=1000, seed=1337)

# %% [markdown]
# ### Total Number of Samples per Label and Determining the Size

# %%
num_of_ai = len(os.listdir(AI_ART_PATH))
num_of_real = len(os.listdir(REAL_ART_PATH))
print(f'Total Number of Images: {num_of_ai + num_of_real} \nNumber of AI: {num_of_ai} \nNumber of Real: {num_of_real}')

ai_train_size = int(num_of_ai * 0.8) # 0.8 split
ai_val_size = num_of_ai - ai_train_size

real_train_size = int(num_of_real * 0.8)
real_val_size = num_of_real - real_train_size
# Out:
# Total Number of Images: 916
# Number of AI: 506
# Number of Real: 410

# %% [markdown]
# ### Train and Validation Split

# %%
ai_train_dataset, ai_val_dataset = split_dataset(ai_dataset, ai_train_size, ai_val_size)
real_train_dataset, real_val_dataset = split_dataset(real_dataset, real_train_size, real_val_size)

target_train_size = min(ai_train_size, real_train_size)
target_val_size = min(ai_val_size, real_val_size)

print(f'Target Sizes of Training: {target_train_size} for Train, and {target_val_size} for Validation')
# Out:
# Target Sizes of Training: 328 for Train, and 82 for Validation

# %% [markdown]
# ### Undersample

# %%
ai_train_dataset = undersample_dataset(ai_train_dataset, target_train_size)
real_train_dataset = undersample_dataset(real_train_dataset, target_train_size)

ai_val_dataset = undersample_dataset(ai_val_dataset, target_val_size)
real_val_dataset = undersample_dataset(real_val_dataset, target_val_size)

# %% [markdown]
# ### Apply Preprocessing

# %%
ai_train_dataset= ai_train_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
real_train_dataset = real_train_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

ai_val_dataset =ai_val_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)
real_val_dataset = real_val_dataset.map(load_and_preprocess_image, num_parallel_calls=tf.data.experimental.AUTOTUNE)

# %% [markdown]
# ### Label Datasets

# %%
ai_train_dataset = label_dataset(ai_train_dataset, 0)
real_train_dataset = label_dataset(real_train_dataset, 1)

ai_val_dataset = label_dataset(ai_val_dataset, 0)
real_val_dataset = label_dataset(real_val_dataset, 1)

# %% [markdown]
# ### Combine Training Datasets and Validation Datasets

# %%
train_dataset = ai_train_dataset.concatenate(real_train_dataset)
train_dataset = train_dataset.shuffle(buffer_size=1000)

val_dataset = ai_val_dataset.concatenate(real_val_dataset)
val_dataset = val_dataset.shuffle(buffer_size=1000)

# %% [markdown]
# ### Batch Datasets

# %%
train_dataset = train_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)

# %% [markdown]
# ### Display Sample Images

# %%
import matplotlib.pyplot as plt

# Function to display images from a dataset
def display_binary_images(dataset, class_names):
    plt.figure(figsize=(10, 10))
    for images, labels in dataset.take(1):
        for i in range(9):
            ax = plt.subplot(3, 3, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[int(labels[i].numpy())])
            plt.axis("off")

class_names = ['AI Art', 'Real Art']

# Display images from the balanced training dataset
display_binary_images(train_dataset, class_names)

# %% [markdown]
# ### Rescale

# %% [markdown]
# ### Data Augmentation

# %%
# augmentation_layers = [
#     keras.layers.RandomFlip("horizontal_and_vertical"),
#     keras.layers.RandomRotation(0.2),
# ]

# def data_augmentation(x):
#     for layer in augmentation_layers:
#         x = layer(x)
#     return x

# train_dataset = train_dataset.map(lambda x, y: (data_augmentation(x), y))

# %% [markdown]
# ### Prefetch Data for Optimization

# %%
from tensorflow import data as tf_data

train_dataset = train_dataset.prefetch(tf_data.AUTOTUNE).cache()
val_dataset = val_dataset.prefetch(tf_data.AUTOTUNE).cache()

# %% [markdown]
# ### Display Data Augmentation

# %%
# for images, labels in train_dataset.take(1):
#     plt.figure(figsize=(10, 10))
#     first_image = images[0]
#     for i in range(9):
#         ax = plt.subplot(3, 3, i + 1)
#         augmented_image = data_augmentation(np.expand_dims(first_image, 0))
#         plt.imshow(np.array(augmented_image[0]).astype("int32"))
#         plt.title(int(labels[0]))
#         plt.axis("off")

# %% [markdown]
# ## Importing InceptionV3 and Base Training

# %% [markdown]
# ### Import InceptionV3 as our base model

# %%
base_model = keras.applications.InceptionV3(
    include_top=False, # Do not include the final layer, which classifies images
    weights="imagenet",
    pooling='avg',
)

# %% [markdown]
# ### Make base model non-trainable

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ## Fine-Tuning the model

# %% [markdown]
# ### Util Methods

# %%
# Dynamic Learning Rate
def lr_schedule(epoch):
    initial_lr = 0.001
    drop = 0.1
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch)
        / epochs_drop))
    return lr

# %%
stop = keras.callbacks.EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor="val_loss",
    start_from_epoch=5,
    verbose=1)

callbacks = [
    stop,
    keras.callbacks.LearningRateScheduler(lr_schedule),
]

# %% [markdown]
# ### Create new Model on Top

# %%
from keras import layers
# Starting layers
inputs = keras.Input(shape=(HEIGHT, WIDTH, 3))
scale_layer = keras.layers.Rescaling(scale=1 / 127.5, offset=-1)
x = scale_layer(inputs)

x = base_model(inputs, training=False) # run in inference mode

x = layers.Flatten()(x)
x = layers.Dense(2056, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.2)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

# %% [markdown]
# ### Compile the Model

# %%
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary(show_trainable=True)

stop = keras.callbacks.EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor="val_loss",
    start_from_epoch=5,
    verbose=1)

callbacks = [
    stop,
    keras.callbacks.LearningRateScheduler(lr_schedule),
]
# Out:
# Model: "model_1"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  inception_v3 (Functional)   (None, 2048)              2180278   Y
#                                                        4
#
#  flatten_1 (Flatten)         (None, 2048)              0         Y
#
#  dense_5 (Dense)             (None, 2056)              4212744   Y
#
#  dropout_4 (Dropout)         (None, 2056)              0         Y
#
#  dense_6 (Dense)             (None, 1024)              2106368   Y
#
#  dropout_5 (Dropout)         (None, 1024)              0         Y
#
#  dense_7 (Dense)             (None, 512)               524800    Y
#
#  dropout_6 (Dropout)         (None, 512)               0         Y
#
#  dense_8 (Dense)             (None, 256)               131328    Y
#
#  dropout_7 (Dropout)         (None, 256)               0         Y
#
#  dense_9 (Dense)             (None, 1)                 257       Y
#
# ============================================================================
# Total params: 28778281 (109.78 MB)
# Trainable params: 6975497 (26.61 MB)
# Non-trainable params: 21802784 (83.17 MB)
# ____________________________________________________________________________

# %% [markdown]
# ### Train the Top Layer

# %%
EPOCHS = 50

model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
    loss=keras.losses.BinaryCrossentropy(),
    metrics= [keras.metrics.BinaryAccuracy()],
)

print("Fitting the top layer of the model")

model.fit(train_dataset,
          epochs=EPOCHS,
          validation_data=val_dataset,
          callbacks=callbacks,
)
# Out:
# Fitting the top layer of the model
# Epoch 1/50
# 11/11 [==============================] - 21s 645ms/step - loss: 69.6809 - binary_accuracy: 0.5122 - val_loss: 3.0726 - val_binary_accuracy: 0.4969 - lr: 0.0010
# Epoch 2/50
# 11/11 [==============================] - 2s 190ms/step - loss: 1.6648 - binary_accuracy: 0.5290 - val_loss: 0.7496 - val_binary_accuracy: 0.5215 - lr: 0.0010
# Epoch 3/50
# 11/11 [==============================] - 2s 190ms/step - loss: 1.2612 - binary_accuracy: 0.5396 - val_loss: 0.6675 - val_binary_accuracy: 0.5583 - lr: 0.0010
# Epoch 4/50
# 11/11 [==============================] - 2s 190ms/step - loss: 0.9131 - binary_accuracy: 0.5503 - val_loss: 1.3939 - val_binary_accuracy: 0.4969 - lr: 0.0010
# Epoch 5/50
# 11/11 [==============================] - 2s 194ms/step - loss: 1.3461 - binary_accuracy: 0.5152 - val_loss: 0.9030 - val_binary_accuracy: 0.5031 - lr: 0.0010
# Epoch 6/50
# 11/11 [==============================] - 3s 254ms/step - loss: 0.8447 - binary_accuracy: 0.5442 - val_loss: 0.7566 - val_binary_accuracy: 0.4969 - lr: 0.0010
# Epoch 7/50
# 11/11 [==============================] - 2s 191ms/step - loss: 0.8318 - binary_accuracy: 0.5671 - val_loss: 4.2212 - val_binary_accuracy: 0.4969 - lr: 0.0010
# Epoch 8/50
# 11/11 [==============================] - 2s 191ms/step - loss: 1.2983 - binary_accuracy: 0.5168 - val_loss: 0.7802 - val_binary_accuracy: 0.5092 - lr: 0.0010
# Epoch 9/50
# 11/11 [==============================] - 2s 207ms/step - loss: 0.7489 - binary_accuracy: 0.5610 - val_loss: 0.7061 - val_binary_accuracy: 0.4969 - lr: 0.0010
# Epoch 10/50
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6820 - binary_accuracy: 0.5793 - val_loss: 0.6441 - val_binary_accuracy: 0.6380 - lr: 1.0000e-04
# Epoch 11/50
# 11/11 [==============================] - 3s 236ms/step - loss: 0.6528 - binary_accuracy: 0.6204 - val_loss: 0.6365 - val_binary_accuracy: 0.6687 - lr: 1.0000e-04
# Epoch 12/50
# 11/11 [==============================] - 2s 212ms/step - loss: 0.6413 - binary_accuracy: 0.6159 - val_loss: 0.6202 - val_binary_accuracy: 0.6871 - lr: 1.0000e-04
# Epoch 13/50
# 11/11 [==============================] - 2s 207ms/step - loss: 0.6430 - binary_accuracy: 0.6159 - val_loss: 0.6131 - val_binary_accuracy: 0.6748 - lr: 1.0000e-04
# Epoch 14/50
# 11/11 [==============================] - 2s 191ms/step - loss: 0.6218 - binary_accuracy: 0.6433 - val_loss: 0.6132 - val_binary_accuracy: 0.6687 - lr: 1.0000e-04
# Epoch 15/50
# 11/11 [==============================] - 2s 208ms/step - loss: 0.6122 - binary_accuracy: 0.6707 - val_loss: 0.5981 - val_binary_accuracy: 0.6871 - lr: 1.0000e-04
# Epoch 16/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.6209 - binary_accuracy: 0.6753 - val_loss: 0.5963 - val_binary_accuracy: 0.7055 - lr: 1.0000e-04
# Epoch 17/50
# 11/11 [==============================] - 2s 219ms/step - loss: 0.6200 - binary_accuracy: 0.6738 - val_loss: 0.5990 - val_binary_accuracy: 0.6933 - lr: 1.0000e-04
# Epoch 18/50
# 11/11 [==============================] - 2s 212ms/step - loss: 0.5960 - binary_accuracy: 0.6905 - val_loss: 0.5869 - val_binary_accuracy: 0.6994 - lr: 1.0000e-04
# Epoch 19/50
# 11/11 [==============================] - 2s 193ms/step - loss: 0.6090 - binary_accuracy: 0.6616 - val_loss: 0.5880 - val_binary_accuracy: 0.6810 - lr: 1.0000e-04
# Epoch 20/50
# 11/11 [==============================] - 2s 207ms/step - loss: 0.5954 - binary_accuracy: 0.6982 - val_loss: 0.5858 - val_binary_accuracy: 0.6994 - lr: 1.0000e-05
# Epoch 21/50
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5956 - binary_accuracy: 0.6875 - val_loss: 0.5841 - val_binary_accuracy: 0.7117 - lr: 1.0000e-05
# Epoch 22/50
# 11/11 [==============================] - 2s 210ms/step - loss: 0.5877 - binary_accuracy: 0.6738 - val_loss: 0.5833 - val_binary_accuracy: 0.7117 - lr: 1.0000e-05
# Epoch 23/50
# 11/11 [==============================] - 3s 238ms/step - loss: 0.5910 - binary_accuracy: 0.6982 - val_loss: 0.5824 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 24/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5789 - binary_accuracy: 0.7012 - val_loss: 0.5812 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 25/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5826 - binary_accuracy: 0.6966 - val_loss: 0.5786 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 26/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5934 - binary_accuracy: 0.6753 - val_loss: 0.5769 - val_binary_accuracy: 0.7178 - lr: 1.0000e-05
# Epoch 27/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5800 - binary_accuracy: 0.6936 - val_loss: 0.5750 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 28/50
# 11/11 [==============================] - 3s 236ms/step - loss: 0.5887 - binary_accuracy: 0.6966 - val_loss: 0.5743 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 29/50
# 11/11 [==============================] - 2s 214ms/step - loss: 0.5744 - binary_accuracy: 0.6997 - val_loss: 0.5731 - val_binary_accuracy: 0.7178 - lr: 1.0000e-05
# Epoch 30/50
# 11/11 [==============================] - 2s 211ms/step - loss: 0.5865 - binary_accuracy: 0.6875 - val_loss: 0.5728 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 31/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5841 - binary_accuracy: 0.6951 - val_loss: 0.5728 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 32/50
# 11/11 [==============================] - 2s 211ms/step - loss: 0.5851 - binary_accuracy: 0.6799 - val_loss: 0.5726 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 33/50
# 11/11 [==============================] - 2s 233ms/step - loss: 0.5782 - binary_accuracy: 0.6768 - val_loss: 0.5725 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 34/50
# 11/11 [==============================] - 2s 228ms/step - loss: 0.5802 - binary_accuracy: 0.6951 - val_loss: 0.5724 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 35/50
# 11/11 [==============================] - 2s 217ms/step - loss: 0.5722 - binary_accuracy: 0.7210 - val_loss: 0.5723 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 36/50
# 11/11 [==============================] - 2s 209ms/step - loss: 0.5721 - binary_accuracy: 0.7119 - val_loss: 0.5721 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 37/50
# 11/11 [==============================] - 2s 208ms/step - loss: 0.5878 - binary_accuracy: 0.7027 - val_loss: 0.5721 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 38/50
# 11/11 [==============================] - 2s 210ms/step - loss: 0.5860 - binary_accuracy: 0.6738 - val_loss: 0.5720 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 39/50
# 11/11 [==============================] - 2s 214ms/step - loss: 0.5760 - binary_accuracy: 0.7073 - val_loss: 0.5719 - val_binary_accuracy: 0.7178 - lr: 1.0000e-06
# Epoch 40/50
# 11/11 [==============================] - 2s 221ms/step - loss: 0.5763 - binary_accuracy: 0.6890 - val_loss: 0.5718 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 41/50
# 11/11 [==============================] - 3s 242ms/step - loss: 0.5929 - binary_accuracy: 0.7027 - val_loss: 0.5718 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 42/50
# 11/11 [==============================] - 2s 214ms/step - loss: 0.5696 - binary_accuracy: 0.6982 - val_loss: 0.5718 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 43/50
# 11/11 [==============================] - 2s 215ms/step - loss: 0.5616 - binary_accuracy: 0.7210 - val_loss: 0.5718 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 44/50
# 11/11 [==============================] - 3s 244ms/step - loss: 0.5721 - binary_accuracy: 0.6890 - val_loss: 0.5718 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 45/50
# 11/11 [==============================] - 2s 212ms/step - loss: 0.5694 - binary_accuracy: 0.6921 - val_loss: 0.5718 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 46/50
# 11/11 [==============================] - 2s 213ms/step - loss: 0.5729 - binary_accuracy: 0.7027 - val_loss: 0.5717 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 47/50
# 11/11 [==============================] - 2s 213ms/step - loss: 0.5868 - binary_accuracy: 0.6845 - val_loss: 0.5717 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 48/50
# 11/11 [==============================] - 2s 221ms/step - loss: 0.5842 - binary_accuracy: 0.6905 - val_loss: 0.5717 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 49/50
# 11/11 [==============================] - 2s 218ms/step - loss: 0.5834 - binary_accuracy: 0.7058 - val_loss: 0.5717 - val_binary_accuracy: 0.7178 - lr: 1.0000e-07
# Epoch 50/50
# 11/11 [==============================] - 2s 195ms/step - loss: 0.5805 - binary_accuracy: 0.7119 - val_loss: 0.5717 - val_binary_accuracy: 0.7178 - lr: 1.0000e-08

# %% [markdown]
# ## Fine Tuning the Model

# %% [markdown]
# ### Util Methods

# %%
# Dynamic Learning Rate
def fine_tuned_lr_schedule(epoch):
    initial_lr = 0.00001
    drop = 0.1
    epochs_drop = 10
    lr = initial_lr * np.power(drop, np.floor((1 + epoch)
        / epochs_drop))
    return lr

# %%
stop = keras.callbacks.EarlyStopping(
    patience=5,
    restore_best_weights=True,
    monitor="val_loss",
    start_from_epoch=5,
    verbose=1)

callbacks = [
    stop,
    keras.callbacks.LearningRateScheduler(fine_tuned_lr_schedule),
]

# %% [markdown]
# ### Unfreeze Layers

# %%
for layer in base_model.layers:
    if isinstance(layer, keras.layers.Conv2D):
        layer.trainable = True

# %%
model.summary(show_trainable=True)

model.compile(
    optimizer=keras.optimizers.RMSprop(learning_rate=0.00001),
    loss=keras.losses.BinaryCrossentropy(),
    metrics= [keras.metrics.BinaryAccuracy()],
)
# Out:
# Model: "model_1"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]     0         Y
#
#  inception_v3 (Functional)   (None, 2048)              2180278   Y
#                                                        4
#
#  flatten_1 (Flatten)         (None, 2048)              0         Y
#
#  dense_5 (Dense)             (None, 2056)              4212744   Y
#
#  dropout_4 (Dropout)         (None, 2056)              0         Y
#
#  dense_6 (Dense)             (None, 1024)              2106368   Y
#
#  dropout_5 (Dropout)         (None, 1024)              0         Y
#
#  dense_7 (Dense)             (None, 512)               524800    Y
#
#  dropout_6 (Dropout)         (None, 512)               0         Y
#
#  dense_8 (Dense)             (None, 256)               131328    Y
#
#  dropout_7 (Dropout)         (None, 256)               0         Y
#
#  dense_9 (Dense)             (None, 1)                 257       Y
#
# ============================================================================
# Total params: 28778281 (109.78 MB)
# Trainable params: 28726633 (109.58 MB)
# Non-trainable params: 51648 (201.75 KB)
# ____________________________________________________________________________

# %%
print("Fitting the end-end model")
fine_tuned_model = model.fit(train_dataset,
          epochs=EPOCHS,
          validation_data=val_dataset,
          callbacks=callbacks,
)
# Out:
# Fitting the end-end model
# Epoch 1/50
# 11/11 [==============================] - 20s 748ms/step - loss: 0.7240 - binary_accuracy: 0.6235 - val_loss: 0.6463 - val_binary_accuracy: 0.6135 - lr: 1.0000e-05
# Epoch 2/50
# 11/11 [==============================] - 7s 604ms/step - loss: 0.6275 - binary_accuracy: 0.6509 - val_loss: 0.6126 - val_binary_accuracy: 0.6748 - lr: 1.0000e-05
# Epoch 3/50
# 11/11 [==============================] - 6s 587ms/step - loss: 0.6088 - binary_accuracy: 0.6555 - val_loss: 0.6069 - val_binary_accuracy: 0.6810 - lr: 1.0000e-05
# Epoch 4/50
# 11/11 [==============================] - 7s 595ms/step - loss: 0.6056 - binary_accuracy: 0.6890 - val_loss: 0.5804 - val_binary_accuracy: 0.7301 - lr: 1.0000e-05
# Epoch 5/50
# 11/11 [==============================] - 7s 591ms/step - loss: 0.5790 - binary_accuracy: 0.6921 - val_loss: 0.5504 - val_binary_accuracy: 0.7914 - lr: 1.0000e-05
# Epoch 6/50
# 11/11 [==============================] - 7s 615ms/step - loss: 0.5553 - binary_accuracy: 0.7302 - val_loss: 0.5540 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 7/50
# 11/11 [==============================] - 7s 604ms/step - loss: 0.5569 - binary_accuracy: 0.6982 - val_loss: 0.5280 - val_binary_accuracy: 0.7791 - lr: 1.0000e-05
# Epoch 8/50
# 11/11 [==============================] - 6s 584ms/step - loss: 0.5064 - binary_accuracy: 0.7515 - val_loss: 0.5861 - val_binary_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 9/50
# 11/11 [==============================] - 7s 621ms/step - loss: 0.5311 - binary_accuracy: 0.7363 - val_loss: 0.5130 - val_binary_accuracy: 0.7301 - lr: 1.0000e-05
# Epoch 10/50
# 11/11 [==============================] - 7s 599ms/step - loss: 0.4802 - binary_accuracy: 0.7622 - val_loss: 0.4674 - val_binary_accuracy: 0.7853 - lr: 1.0000e-06
# Epoch 11/50
# 11/11 [==============================] - 7s 609ms/step - loss: 0.4353 - binary_accuracy: 0.8171 - val_loss: 0.4546 - val_binary_accuracy: 0.7975 - lr: 1.0000e-06
# Epoch 12/50
# 11/11 [==============================] - 7s 600ms/step - loss: 0.4211 - binary_accuracy: 0.8186 - val_loss: 0.4474 - val_binary_accuracy: 0.7975 - lr: 1.0000e-06
# Epoch 13/50
# 11/11 [==============================] - 7s 628ms/step - loss: 0.4141 - binary_accuracy: 0.8201 - val_loss: 0.4350 - val_binary_accuracy: 0.8037 - lr: 1.0000e-06
# Epoch 14/50
# 11/11 [==============================] - 7s 600ms/step - loss: 0.4141 - binary_accuracy: 0.8232 - val_loss: 0.4341 - val_binary_accuracy: 0.8037 - lr: 1.0000e-06
# Epoch 15/50
# 11/11 [==============================] - 7s 606ms/step - loss: 0.4007 - binary_accuracy: 0.8247 - val_loss: 0.4270 - val_binary_accuracy: 0.8098 - lr: 1.0000e-06
# Epoch 16/50
# 11/11 [==============================] - 7s 601ms/step - loss: 0.3963 - binary_accuracy: 0.8354 - val_loss: 0.4191 - val_binary_accuracy: 0.8160 - lr: 1.0000e-06
# Epoch 17/50
# 11/11 [==============================] - 7s 608ms/step - loss: 0.3876 - binary_accuracy: 0.8338 - val_loss: 0.4067 - val_binary_accuracy: 0.8098 - lr: 1.0000e-06
# Epoch 18/50
# 11/11 [==============================] - 7s 600ms/step - loss: 0.3781 - binary_accuracy: 0.8277 - val_loss: 0.4052 - val_binary_accuracy: 0.8160 - lr: 1.0000e-06
# Epoch 19/50
# 11/11 [==============================] - 7s 603ms/step - loss: 0.3766 - binary_accuracy: 0.8338 - val_loss: 0.3981 - val_binary_accuracy: 0.8282 - lr: 1.0000e-06
# Epoch 20/50
# 11/11 [==============================] - 7s 605ms/step - loss: 0.3685 - binary_accuracy: 0.8506 - val_loss: 0.3968 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 21/50
# 11/11 [==============================] - 6s 585ms/step - loss: 0.3684 - binary_accuracy: 0.8262 - val_loss: 0.3968 - val_binary_accuracy: 0.8282 - lr: 1.0000e-07
# Epoch 22/50
# 11/11 [==============================] - 7s 629ms/step - loss: 0.3502 - binary_accuracy: 0.8598 - val_loss: 0.3964 - val_binary_accuracy: 0.8221 - lr: 1.0000e-07
# Epoch 23/50
# 11/11 [==============================] - 7s 600ms/step - loss: 0.3697 - binary_accuracy: 0.8552 - val_loss: 0.3961 - val_binary_accuracy: 0.8282 - lr: 1.0000e-07
# Epoch 24/50
# 11/11 [==============================] - 7s 605ms/step - loss: 0.3742 - binary_accuracy: 0.8552 - val_loss: 0.3939 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 25/50
# 11/11 [==============================] - 7s 601ms/step - loss: 0.3592 - binary_accuracy: 0.8521 - val_loss: 0.3933 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 26/50
# 11/11 [==============================] - 7s 605ms/step - loss: 0.3719 - binary_accuracy: 0.8430 - val_loss: 0.3916 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 27/50
# 11/11 [==============================] - 7s 601ms/step - loss: 0.3654 - binary_accuracy: 0.8460 - val_loss: 0.3913 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 28/50
# 11/11 [==============================] - 7s 605ms/step - loss: 0.3626 - binary_accuracy: 0.8567 - val_loss: 0.3909 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 29/50
# 11/11 [==============================] - 7s 606ms/step - loss: 0.3540 - binary_accuracy: 0.8628 - val_loss: 0.3900 - val_binary_accuracy: 0.8344 - lr: 1.0000e-07
# Epoch 30/50
# 11/11 [==============================] - 6s 588ms/step - loss: 0.3628 - binary_accuracy: 0.8384 - val_loss: 0.3900 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 31/50
# 11/11 [==============================] - 7s 599ms/step - loss: 0.3753 - binary_accuracy: 0.8567 - val_loss: 0.3899 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 32/50
# 11/11 [==============================] - 7s 605ms/step - loss: 0.3596 - binary_accuracy: 0.8491 - val_loss: 0.3899 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 33/50
# 11/11 [==============================] - 7s 602ms/step - loss: 0.3666 - binary_accuracy: 0.8445 - val_loss: 0.3901 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 34/50
# 11/11 [==============================] - 6s 586ms/step - loss: 0.3594 - binary_accuracy: 0.8643 - val_loss: 0.3901 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 35/50
# 11/11 [==============================] - 7s 587ms/step - loss: 0.3547 - binary_accuracy: 0.8598 - val_loss: 0.3901 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 36/50
# 11/11 [==============================] - 6s 586ms/step - loss: 0.3616 - binary_accuracy: 0.8491 - val_loss: 0.3900 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 37/50
# 11/11 [==============================] - ETA: 0s - loss: 0.3561 - binary_accuracy: 0.8537Restoring model weights from the end of the best epoch: 32.
# 11/11 [==============================] - 7s 618ms/step - loss: 0.3561 - binary_accuracy: 0.8537 - val_loss: 0.3900 - val_binary_accuracy: 0.8344 - lr: 1.0000e-08
# Epoch 37: early stopping

# %% [markdown]
# ## Evaluation of the Model

# %% [markdown]
# ### Predicting a Specific Image

# %%
# img_path = "dataset/AI Art vs Real Art/Real/RealArt/-man-sits-with-a-woman-on-her-phone-at-a-table-while-looking-at-a-computer_l.jpeg"
img_path = "/content/drive/MyDrive/dataset/AI Art vs Real Art/Real/RealArt/-man-sits-with-a-woman-on-her-phone-at-a-table-while-looking-at-a-computer_l.jpeg"

img = keras.preprocessing.image.load_img(img_path,
                                            target_size=(HEIGHT, WIDTH))
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Make predictions
predictions = model.predict(img_array)[0]

print(f"Predictions: {predictions}")

# Interpret the prediction (assuming binary classification with 0 for Real Art and 1 for AI Art)
# Ensure predictions is in the correct format
if len(predictions.shape) == 1:
    predicted_class = 'Real Art' if predictions[0] > 0.5 else 'AI Art'
else:
    predicted_class = 'Real Art' if predictions[0][0] > 0.5 else 'AI Art'

# Create a string with the predicted label
result_string = f'The predicted class for the image {img_path} is: {predicted_class}'
print(result_string)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predictions: [0.7960393]
# The predicted class for the image /content/drive/MyDrive/dataset/AI Art vs Real Art/Real/RealArt/-man-sits-with-a-woman-on-her-phone-at-a-table-while-looking-at-a-computer_l.jpeg is: Real Art

# %% [markdown]
# ### Predicting a Random Image

# %%
import os
import random
folder_number = random.randint(1, 2)  # Generate a random number between 1-3
# if folder_number == 1:
#     dataset_dir = "dataset/AI Art vs Real Art/AI Art/AiArtData"
# else:
#     dataset_dir = "dataset/AI Art vs Real Art/Real/RealArt"

if folder_number == 1:
    dataset_dir = "/content/drive/MyDrive/dataset/AI Art vs Real Art/AI Art/AiArtData"
else:
    dataset_dir = "/content/drive/MyDrive/dataset/AI Art vs Real Art/Real/RealArt"
print(dataset_dir)
file_list = os.listdir(dataset_dir)

random_file = random.choice(file_list)
image_path = os.path.join(dataset_dir, random_file)

img = tf.keras.preprocessing.image.load_img(image_path,
                                            target_size=(HEIGHT, WIDTH))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

# Make predictions
predictions = model.predict(img_array)[0]

print(f"Predictions: {predictions}")

# Interpret the prediction (assuming binary classification with 0 for Real Art and 1 for AI Art)
# Ensure predictions is in the correct format
if len(predictions.shape) == 1:
    predicted_class = 'Real Art' if predictions[0] > 0.5 else 'AI Art'
else:
    predicted_class = 'Real Art' if predictions[0][0] > 0.5 else 'AI Art'

# Create a string with the predicted label
result_string = f'The predicted class for the image {random_file} is: {predicted_class}'
print(result_string)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# /content/drive/MyDrive/dataset/AI Art vs Real Art/AI Art/AiArtData
# 1/1 [==============================] - 0s 25ms/step
# Predictions: [0.02794051]
# The predicted class for the image 4D0B10FA-D43F-427A-8F12-084A42A52081-63ef4da8f2ef6-jpeg__700.jpeg is: AI Art

# %% [markdown]
# ### Visualization in terms of Epochs

# %%
acc = fine_tuned_model.history['binary_accuracy']
val_acc = fine_tuned_model.history['val_binary_accuracy']

loss = fine_tuned_model.history['loss']
val_loss = fine_tuned_model.history['val_loss']
if stop.stopped_epoch != 0:
    epochs_range = range(stop.stopped_epoch+1)
else:
    epochs_range = range(EPOCHS)
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
